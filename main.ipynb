# %% [markdown]
# # TUGAS BESAR MATEMATIK LANJUT
#
# **Nama-nama Kelompok:**
# - SADAM AL RASYID
# - MUHAMMAD ABYAN HARITS
# - RR MEIDITA THIFAL LELYTA
# - KARINA NURLITA SALSABILA

# %%
# ============================================================================
# Linear Regression dengan L1 (Lasso) dan L2 (Ridge) Regularization
# Implementasi GD dan SGD
# ============================================================================
"""
Notebook ini mengimplementasikan regresi linier dengan regularisasi L1 (Lasso) dan L2 (Ridge)
menggunakan Gradient Descent (GD) dan Stochastic Gradient Descent (SGD).
Setiap kombinasi hyperparameter diuji, dievaluasi dengan MSE dan R²,
serta visualisasi konvergensi loss dan perbandingan kecepatan konvergensi.
"""

# =============================================================================
# 1. PERSIAPAN DATA DAN IMPORT LIBRARY
# =============================================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import time
from itertools import product
from tqdm import tqdm

# Set styling untuk visualisasi
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("notebook", font_scale=1.1)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# =============================================================================
# 1.1 LOAD DAN INSPEKSI DATASET
# =============================================================================
# Load dataset (Medical Cost Personal Dataset)
df = pd.read_csv('Medical Cost Personal.csv')
print("="*80)
print("DATASET OVERVIEW")
print("="*80)
print(f"Dataset Shape: {df.shape}")
print("\nPeek at data:")
print(df.head())

# Info dan ringkasan statistik dataset
print("\nInformasi Dataset:")
print(df.info())
print("\nRingkasan Statistik:")
print(df.describe())

# Cek missing values
print("\nJumlah Missing Values per Kolom:")
print(df.isnull().sum())

# =============================================================================
# 1.2 PREPROCESSING DATA
# =============================================================================
# Drop missing values (jika ada)
df.dropna(inplace=True)

# One-hot encoding untuk variabel kategorikal
print("\nKolom sebelum encoding:")
print(df.columns.tolist())
df_encoded = pd.get_dummies(df, drop_first=True).astype(float)
print("\nKolom setelah encoding:")
print(df_encoded.columns.tolist())

# Pisahkan fitur dan target
y = df_encoded.pop('charges').values
X = df_encoded.values

# Standardisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data menjadi train-test (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Tambahkan bias (intercept)
def add_bias(X):
    return np.hstack([np.ones((X.shape[0], 1)), X])

X_train_bias = add_bias(X_train)
X_test_bias = add_bias(X_test)

print(f"\nDimensi Data Training setelah preprocessing: {X_train_bias.shape}")
print(f"Dimensi Data Testing setelah preprocessing: {X_test_bias.shape}")

# =============================================================================
# 2. EXPLORATORY DATA ANALYSIS (EDA)
# =============================================================================
print("\n" + "="*80)
print("EXPLORATORY DATA ANALYSIS")
print("="*80)

# 2.1 Distribusi target variable (charges)
plt.figure(figsize=(10, 6))
sns.histplot(df['charges'], bins=30, kde=True, color='#3498db')
plt.title('Distribusi Biaya (Charges)', fontsize=15, fontweight='bold')
plt.xlabel('Charges', fontsize=12)
plt.ylabel('Frekuensi', fontsize=12)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('charges_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# 2.2 Matriks korelasi fitur
plt.figure(figsize=(12, 10))
correlation_matrix = df_encoded.corr()
mask = np.triu(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            mask=mask, linewidths=0.5, annot_kws={"size": 10})
plt.title('Matriks Korelasi Fitur', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('correlation_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# 2.3 Scatter plot antara fitur numerik dan target
numeric_cols = ['age', 'bmi', 'children']
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
colors_palette = ['#3498db', '#2ecc71', '#e74c3c']

for i, col in enumerate(numeric_cols):
    sns.scatterplot(data=df, x=col, y='charges', ax=axes[i], color=colors_palette[i], alpha=0.7, edgecolor='k', s=70)
    axes[i].set_title(f'Charges vs {col.capitalize()}', fontsize=13, fontweight='bold')
    axes[i].set_xlabel(col.capitalize(), fontsize=11)
    axes[i].set_ylabel('Charges', fontsize=11)
    axes[i].grid(True, alpha=0.3, linestyle='--')

plt.tight_layout()
plt.savefig('feature_target_relationships.png', dpi=300, bbox_inches='tight')
plt.show()

# 2.4 Box plot untuk fitur kategorikal
categorical_cols = ['sex', 'smoker', 'region']
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
colors_palette = ['#9b59b6', '#f39c12', '#1abc9c']

for i, col in enumerate(categorical_cols):
    sns.boxplot(data=df, x=col, y='charges', ax=axes[i], palette=[colors_palette[i], '#bdc3c7'])
    axes[i].set_title(f'Charges by {col.capitalize()}', fontsize=13, fontweight='bold')
    axes[i].set_xlabel(col.capitalize(), fontsize=11)
    axes[i].set_ylabel('Charges', fontsize=11)
    axes[i].grid(True, alpha=0.3, linestyle='--')

plt.tight_layout()
plt.savefig('categorical_features_boxplots.png', dpi=300, bbox_inches='tight')
plt.show()

# =============================================================================
# 3. DEFINISI MODEL REGRESI LINEAR DENGAN REGULARISASI
# =============================================================================
class LinearRegressionGD:
    """
    Implementasi Linear Regression dengan Gradient Descent dan regularisasi.

    Parameters:
    -----------
    lr : float
        Learning rate untuk gradient descent
    epochs : int
        Jumlah epochs untuk training
    penalty : {None, 'l1', 'l2'}, default=None
        Tipe regularisasi: None=tanpa regularisasi, 'l1'=Lasso, 'l2'=Ridge
    lam : float, default=0.0
        Parameter regularisasi lambda
    batch_size : int atau None, default=None
        Ukuran batch untuk SGD. None = full batch GD
    """

    def __init__(self, lr=0.01, epochs=1000, penalty=None, lam=0.0, batch_size=None):
        self.lr = lr
        self.epochs = epochs
        self.penalty = penalty  # None, 'l1', 'l2'
        self.lam = lam
        self.batch_size = batch_size
        self.theta = None
        self.history = []  # untuk menyimpan loss per epoch
        self.theta_history = []  # untuk menyimpan koefisien per epoch

    def _compute_gradient(self, X_batch, y_batch):
        """Menghitung gradient dari loss function dengan/tanpa regularisasi"""
        m = X_batch.shape[0]
        preds = X_batch.dot(self.theta)
        error = preds - y_batch

        # Gradient dari MSE
        grad = X_batch.T.dot(error) / m

        # Tambahkan gradient dari penalty regularisasi
        if self.penalty == 'l2':  # Ridge: L2 penalty
            # Tidak menerapkan regularisasi pada bias (theta[0])
            grad[1:] += (self.lam / m) * self.theta[1:]
        elif self.penalty == 'l1':  # Lasso: L1 penalty
            # Tidak menerapkan regularisasi pada bias (theta[0])
            grad[1:] += (self.lam / m) * np.sign(self.theta[1:])

        return grad

    def _compute_loss(self, X, y):
        """Menghitung loss (MSE + regularisasi)"""
        m = X.shape[0]
        preds = X.dot(self.theta)
        mse = np.mean((preds - y) ** 2)

        # Tambahkan penalty regularisasi ke loss
        if self.penalty == 'l2':  # Ridge: L2 penalty
            mse += (self.lam / (2 * m)) * np.sum(self.theta[1:] ** 2)
        elif self.penalty == 'l1':  # Lasso: L1 penalty
            mse += (self.lam / m) * np.sum(np.abs(self.theta[1:]))

        return mse

    def fit(self, X, y):
        """Fit model dengan Gradient Descent atau Stochastic Gradient Descent"""
        n_samples, n_features = X.shape
        self.theta = np.zeros(n_features)

        # Tentukan batch size
        bs = self.batch_size if self.batch_size else n_samples

        # Training loop
        for epoch in range(self.epochs):
            # Shuffle data untuk SGD
            if bs < n_samples:
                indices = np.random.permutation(n_samples)
                X_shuffled, y_shuffled = X[indices], y[indices]
            else:
                X_shuffled, y_shuffled = X, y

            # Mini-batch updates
            for start_idx in range(0, n_samples, bs):
                end_idx = min(start_idx + bs, n_samples)
                X_batch = X_shuffled[start_idx:end_idx]
                y_batch = y_shuffled[start_idx:end_idx]

                # Hitung gradient dan update parameters
                grad = self._compute_gradient(X_batch, y_batch)
                self.theta -= self.lr * grad

                # Early stopping jika weights tidak finite
                if not np.isfinite(self.theta).all():
                    print(f"Warning: Non-finite weights detected at epoch {epoch}. Training stopped.")
                    return self

            # Hitung dan simpan loss tiap epoch
            loss = self._compute_loss(X, y)
            self.history.append(loss)

            # Simpan theta history untuk analisis
            self.theta_history.append(self.theta.copy())

            # Early stopping jika loss tidak finite atau terlalu kecil (konvergen)
            if not np.isfinite(loss):
                print(f"Warning: Non-finite loss detected at epoch {epoch}. Training stopped.")
                return self

            # Print progress setiap 100 epoch atau di epoch terakhir
            if epoch % 100 == 0 or epoch == self.epochs - 1:
                print(f"Epoch {epoch}/{self.epochs}, Loss: {loss:.6f}")

        return self

    def predict(self, X):
        """Prediksi dengan model yang sudah dilatih"""
        return X.dot(self.theta)

    def get_params(self):
        """Return model parameters"""
        return {'intercept': self.theta[0], 'coefficients': self.theta[1:]}

# =============================================================================
# 4. PENGATURAN HYPERPARAMETER DAN TUNING
# =============================================================================
print("\n" + "="*80)
print("HYPERPARAMETER TUNING")
print("="*80)

# Definisi hyperparameter untuk di-tuning
hyperparams = {
    'lr': [0.01, 0.1, 0.5, 1.0],
    'epochs': [100, 500, 1000],
    'batch_size': [1, 16, 32, None],
    'lam': [0.001, 0.01, 0.1, 1.0]
}

# Buat semua kombinasi hyperparameter
combinations = []
for penalty in [None, 'l1', 'l2']:
    # Hanya menggunakan lambda > 0 jika ada regularisasi
    lam_list = hyperparams['lam'] if penalty else [0.0]

    for lr, epochs, bs, lam in product(
        hyperparams['lr'],
        hyperparams['epochs'],
        hyperparams['batch_size'],
        lam_list
    ):
        combinations.append({
            'penalty': penalty,
            'lr': lr,
            'epochs': epochs,
            'batch_size': bs,
            'lam': lam
        })

print(f"Total kombinasi hyperparameter: {len(combinations)}")

# Proses tuning dengan semua kombinasi
results = []
for params in tqdm(combinations, desc='Tuning Models'):
    # Set parameter untuk model ini
    model_params = params.copy()

    try:
        # Catat waktu mulai
        t0 = time.time()

        # Inisialisasi dan latih model
        model = LinearRegressionGD(**model_params)
        model.fit(X_train_bias, y_train)

        # Prediksi pada data test
        y_pred = model.predict(X_test_bias)

        # Evaluasi model
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        # Catat waktu selesai
        t1 = time.time()

        # Simpan hasil
        results.append({
            'Penalty': params['penalty'] if params['penalty'] else 'None',
            'Learning Rate': params['lr'],
            'Epochs': params['epochs'],
            'Batch Size': params['batch_size'] if params['batch_size'] else 'Full',
            'Lambda': params['lam'],
            'MSE': mse,
            'R2': r2,
            'Training Time (s)': t1 - t0
        })
    except Exception as e:
        print(f"Error with params {params}: {e}")
        results.append({
            'Penalty': params['penalty'] if params['penalty'] else 'None',
            'Learning Rate': params['lr'],
            'Epochs': params['epochs'],
            'Batch Size': params['batch_size'] if params['batch_size'] else 'Full',
            'Lambda': params['lam'],
            'MSE': np.nan,
            'R2': np.nan,
            'Training Time (s)': np.nan
        })

# =============================================================================
# 5. EVALUASI MODEL
# =============================================================================
print("\n" + "="*80)
print("EVALUASI MODEL")
print("="*80)

# Buat DataFrame hasil dan hapus baris dengan nilai NaN
results_df = pd.DataFrame(results).dropna()

# Urutkan berdasarkan MSE (dari terendah ke tertinggi)
sorted_results = results_df.sort_values('MSE').reset_index(drop=True)

# Cetak 10 model terbaik
print("\nTop 10 Model Berdasarkan MSE Terendah:")
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
print(sorted_results.head(10))

# 5.1 Pilih model terbaik berdasarkan MSE untuk analisis lebih lanjut
best_model_params = sorted_results.iloc[0].to_dict()
print("\nParameter Model Terbaik:")
for key, value in {k: best_model_params[k] for k in
                  ['Penalty', 'Learning Rate', 'Epochs', 'Batch Size', 'Lambda']}.items():
    print(f"{key}: {value}")

# 5.2 Visualisasi perbandingan performa model berdasarkan tipe regularisasi
plt.figure(figsize=(12, 6))
sns.boxplot(x='Penalty', y='MSE', data=results_df, palette=['#3498db', '#e74c3c', '#2ecc71'])
plt.title('Perbandingan MSE Berdasarkan Tipe Regularisasi', fontsize=15, fontweight='bold')
plt.xlabel('Tipe Regularisasi', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('regularization_comparison_mse.png', dpi=300, bbox_inches='tight')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Penalty', y='R2', data=results_df, palette=['#3498db', '#e74c3c', '#2ecc71'])
plt.title('Perbandingan R² Berdasarkan Tipe Regularisasi', fontsize=15, fontweight='bold')
plt.xlabel('Tipe Regularisasi', fontsize=12)
plt.ylabel('R² Score', fontsize=12)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('regularization_comparison_r2.png', dpi=300, bbox_inches='tight')
plt.show()

# 5.3 Visualisasi perbandingan performa model berdasarkan batch size
plt.figure(figsize=(12, 6))
sns.boxplot(x='Batch Size', y='MSE', data=results_df, palette=['#f39c12', '#9b59b6', '#1abc9c', '#34495e'])
plt.title('Perbandingan MSE Berdasarkan Ukuran Batch', fontsize=15, fontweight='bold')
plt.xlabel('Ukuran Batch', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('batch_size_comparison_mse.png', dpi=300, bbox_inches='tight')
plt.show()

# 5.4 Visualisasi pengaruh learning rate
plt.figure(figsize=(12, 6))
sns.boxplot(x='Learning Rate', y='MSE', data=results_df, palette=['#1abc9c', '#3498db', '#9b59b6', '#e74c3c'])
plt.title('Perbandingan MSE Berdasarkan Learning Rate', fontsize=15, fontweight='bold')
plt.xlabel('Learning Rate', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('learning_rate_comparison_mse.png', dpi=300, bbox_inches='tight')
plt.show()

# =============================================================================
# 6. PERBANDINGAN GD VS SGD
# =============================================================================
print("\n" + "="*80)
print("PERBANDINGAN GD VS SGD")
print("="*80)

# 6.1 Latih model GD (full-batch) dan SGD dengan parameter terbaik
penalty_best = 'l2' if best_model_params['Penalty'] == 'l2' else ('l1' if best_model_params['Penalty'] == 'l1' else None)
lr_best = best_model_params['Learning Rate']
lam_best = best_model_params['Lambda']
epochs = 500  # menggunakan 500 epochs untuk visualisasi yang jelas

# Latih dengan GD (full-batch)
print("Training model GD (full-batch)...")
model_gd = LinearRegressionGD(
    lr=lr_best,
    epochs=epochs,
    penalty=penalty_best,
    lam=lam_best,
    batch_size=None
).fit(X_train_bias, y_train)

# Latih dengan SGD (batch_size=1)
print("Training model SGD (batch_size=1)...")
model_sgd = LinearRegressionGD(
    lr=lr_best,
    epochs=epochs,
    penalty=penalty_best,
    lam=lam_best,
    batch_size=1
).fit(X_train_bias, y_train)

# Latih dengan mini-batch SGD (batch_size=16)
print("Training model mini-batch SGD (batch_size=16)...")
model_mini_batch = LinearRegressionGD(
    lr=lr_best,
    epochs=epochs,
    penalty=penalty_best,
    lam=lam_best,
    batch_size=16
).fit(X_train_bias, y_train)

# 6.2 Visualisasi perbandingan konvergensi loss
plt.figure(figsize=(12, 6))
plt.plot(model_gd.history, label='GD (Full-batch)', color='#3498db', linewidth=2)
plt.plot(model_sgd.history, label='SGD (Batch=1)', color='#e74c3c', linewidth=2, alpha=0.6)
plt.plot(model_mini_batch.history, label='Mini-batch SGD (Batch=16)', color='#2ecc71', linewidth=2)
plt.title('Perbandingan Konvergensi Loss: GD vs SGD vs Mini-batch', fontsize=15, fontweight='bold')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('gd_vs_sgd_convergence.png', dpi=300, bbox_inches='tight')
plt.show()

# 6.3 Analisis dengan smoothing untuk SGD (karena fluktuatif)
def smooth(y, box_pts):
    box = np.ones(box_pts) / box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

plt.figure(figsize=(12, 6))
plt.plot(model_gd.history, label='GD (Full-batch)', color='#3498db', linewidth=2)
plt.plot(smooth(model_sgd.history, 20), label='SGD (Batch=1, Smoothed)', color='#e74c3c', linewidth=2)
plt.plot(smooth(model_mini_batch.history, 10), label='Mini-batch (Batch=16, Smoothed)', color='#2ecc71', linewidth=2)
plt.title('Perbandingan Konvergensi Loss dengan Smoothing', fontsize=15, fontweight='bold')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('smoothed_convergence_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# 6.4 Visualisasi efek regularisasi pada koefisien
# Latih model dengan regularisasi berbeda (tanpa, L1, L2)
models_reg = {}
for penalty in [None, 'l1', 'l2']:
    name = "No Regularization" if penalty is None else f"{penalty} Regularization"
    print(f"Training model dengan {name}...")
    models_reg[name] = LinearRegressionGD(
        lr=0.1,
        epochs=500,
        penalty=penalty,
        lam=0.1 if penalty else 0.0,
        batch_size=None
    ).fit(X_train_bias, y_train)

# Plot perbandingan koefisien
coef_labels = ['Intercept'] + [f'Coef {i+1}' for i in range(X_train.shape[1])]
coef_data = []

for name, model in models_reg.items():
    coefs = model.theta
    coef_data.append(pd.Series(coefs, index=coef_labels, name=name))

coef_df = pd.DataFrame(coef_data).T

plt.figure(figsize=(12, 8))
colors = ['#3498db', '#e74c3c', '#2ecc71']
coef_df.plot(kind='bar', figsize=(12, 8), color=colors)
plt.title('Perbandingan Koefisien dengan Berbagai Tipe Regularisasi', fontsize=15, fontweight='bold')
plt.xlabel('Koefisien', fontsize=12)
plt.ylabel('Nilai', fontsize=12)
plt.legend(title='Regularisasi', fontsize=10)
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.savefig('coefficient_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# =============================================================================
# 7. ANALISIS HASIL DAN PENYAJIAN COMPREHENSIF
# =============================================================================
print("\n" + "="*80)
print("ANALISIS HASIL AKHIR")
print("="*80)

# Buat tabel perbandingan model terbaik dengan format yang lebih rapi
best_model_table = f"""
╔══════════════════════════════════════════════════════════════════╗
║                    KONFIGURASI MODEL TERBAIK                     ║
╠════════════════════════╦═══════════════════════════════════════════╣
║ Parameter              ║ Nilai                                     ║
╠════════════════════════╬═══════════════════════════════════════════╣
║ Regularisasi           ║ {best_model_params['Penalty']}            ║
║ Learning Rate          ║ {best_model_params['Learning Rate']}      ║
║ Lambda                 ║ {best_model_params['Lambda']}             ║
║ Batch Size             ║ {best_model_params['Batch Size']}         ║
║ Epochs                 ║ {best_model_params['Epochs']}             ║
╠════════════════════════╬═══════════════════════════════════════════╣
║ MSE                    ║ {best_model_params['MSE']:.4f}            ║
║ R²                     ║ {best_model_params['R2']:.4f}             ║
║ Training Time          ║ {best_model_params['Training Time (s)']:.2f} detik ║
╚════════════════════════╩═══════════════════════════════════════════╝
"""
print(best_model_table)

# Analisis yang lebih terstruktur dan rapi
analysis_results = """
╔══════════════════════════════════════════════════════════════════╗
║                     ANALISIS PERBANDINGAN MODEL                  ║
╚══════════════════════════════════════════════════════════════════╝

1️⃣ PERBANDINGAN GD DAN SGD
   ✓ GD (full-batch):
     • Lebih stabil dan konsisten
     • Memerlukan lebih banyak iterasi untuk konvergen
     • Komputasi lebih berat per iterasi

   ✓ SGD (batch=1):
     • Lebih cepat per iterasi
     • Loss curve lebih fluktuatif (noisy)
     • Update parameter lebih sering

   ✓ Mini-batch SGD:
     • Menawarkan keseimbangan antara kecepatan dan stabilitas
     • Mengurangi noise dibandingkan SGD murni
     • Lebih efisien secara komputasi dibanding full-batch GD

2️⃣ PENGARUH LEARNING RATE
   ✓ Learning rate kecil (0.01):
     • Konvergensi lambat tetapi stabil
     • Risiko terjebak di local minimum tinggi
     • Cocok untuk data kompleks dengan noise rendah

   ✓ Learning rate besar (0.5-1.0):
     • Mempercepat konvergensi
     • Berisiko osilasi atau divergensi
     • Memerlukan scheduling atau adaptive rate untuk stabilitas

   ✓ Kesimpulan:
     • Learning rate optimal tergantung pada dataset dan kompleksitas model
     • Dalam kasus ini, learning rate optimal adalah {best_model_params['Learning Rate']}

3️⃣ PERBEDAAN L1 VS L2 REGULARIZATION
   ✓ L1 (Lasso):
     • Cenderung menghasilkan sparsity pada koefisien (beberapa mendekati nol)
     • Berguna untuk feature selection dan model sederhana
     • Cocok untuk dataset dengan fitur redundan

   ✓ L2 (Ridge):
     • Melakukan shrinkage pada semua koefisien secara merata
     • Lebih stabil untuk kolinearitas tinggi
     • Cocok untuk mengatasi overfitting tanpa menghilangkan fitur

   ✓ Kesimpulan:
     • Pemilihan regularisasi tergantung pada kebutuhan spesifik
     • Untuk dataset ini, {best_model_params['Penalty']} regularization optimal

4️⃣ EFEK BATCH SIZE PADA SGD
   ✓ Batch kecil (1):
     • Update lebih noisy tetapi lebih sering
     • Dapat menemukan solusi inovatif pada permukaan loss kompleks
     • Komputasi ringan per iterasi

   ✓ Batch besar:
     • Update lebih stabil dan konsisten
     • Komputasi per iterasi lebih tinggi
     • Konvergensi lebih terprediksi

   ✓ Mini-batch (16, 32):
     • Keseimbangan yang baik antara stabilitas dan efisiensi komputasi
     • Umumnya menghasilkan performa model yang lebih baik secara keseluruhan
"""
# Out:
# ================================================================================
# DATASET OVERVIEW
# ================================================================================
# Dataset Shape: (1338, 7)
#
# Peek at data:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None
#
# Ringkasan Statistik:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010
#
# Jumlah Missing Values per Kolom:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64
#
# Kolom sebelum encoding:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
#
# Kolom setelah encoding:
# ['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest']
#
# Dimensi Data Training setelah preprocessing: (1070, 9)
# Dimensi Data Testing setelah preprocessing: (268, 9)
#
# ================================================================================
# EXPLORATORY DATA ANALYSIS
# ================================================================================
# <ipython-input-5-5f24788bf935>:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='charges', ax=axes[i], palette=[colors_palette[i], '#bdc3c7'])
# <ipython-input-5-5f24788bf935>:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='charges', ax=axes[i], palette=[colors_palette[i], '#bdc3c7'])
# <ipython-input-5-5f24788bf935>:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='charges', ax=axes[i], palette=[colors_palette[i], '#bdc3c7'])
# <ipython-input-5-5f24788bf935>:140: UserWarning:
# The palette list has fewer values (2) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(data=df, x=col, y='charges', ax=axes[i], palette=[colors_palette[i], '#bdc3c7'])
# ================================================================================
# HYPERPARAMETER TUNING
# ================================================================================
# Total kombinasi hyperparameter: 432
# Tuning Models:   0%|          | 0/432 [00:00<?, ?it/s]
# Epoch 0/100, Loss: 39203113.202871
# Tuning Models:   1%|          | 4/432 [00:00<01:20,  5.32it/s]
# Epoch 99/100, Loss: 38734694.734312
# Epoch 0/100, Loss: 110609716.199884
# Epoch 99/100, Loss: 37282242.562859
# Epoch 0/100, Loss: 180167917.647925
# Epoch 99/100, Loss: 37279517.178611
# Epoch 0/100, Loss: 316757221.378228
# Epoch 99/100, Loss: 75734470.438583
# Epoch 0/500, Loss: 39076180.370105
# Epoch 100/500, Loss: 37804287.223546
# Epoch 200/500, Loss: 38315773.041904
# Epoch 300/500, Loss: 39363705.582262
# Epoch 400/500, Loss: 41487362.941418
# Epoch 499/500, Loss: 37790093.416222
# Epoch 0/500, Loss: 110923817.049664
# Epoch 100/500, Loss: 37284639.948679
# Epoch 200/500, Loss: 37282882.079116
# Epoch 300/500, Loss: 37281084.285280
# Tuning Models:   1%|▏         | 6/432 [00:05<07:46,  1.09s/it]
# Epoch 400/500, Loss: 37284760.480600
# Epoch 499/500, Loss: 37280764.791343
# Epoch 0/500, Loss: 182056074.634946
# Epoch 100/500, Loss: 37279289.113687
# Epoch 200/500, Loss: 37283173.752392
# Epoch 300/500, Loss: 37280492.663834
# Epoch 400/500, Loss: 37278703.846568
# Tuning Models:   2%|▏         | 7/432 [00:05<06:12,  1.14it/s]
# Epoch 499/500, Loss: 37279554.324919
# Epoch 0/500, Loss: 316757221.378228
# Epoch 100/500, Loss: 74976514.346122
# Epoch 200/500, Loss: 42493150.242596
# Epoch 300/500, Loss: 38020613.415051
# Epoch 400/500, Loss: 37389046.811109
# Epoch 499/500, Loss: 37296808.775831
# Epoch 0/1000, Loss: 38864518.155135
# Epoch 100/1000, Loss: 40061949.125308
# Epoch 200/1000, Loss: 38769673.849128
# Epoch 300/1000, Loss: 39362538.892993
# Epoch 400/1000, Loss: 39372686.142983
# Epoch 500/1000, Loss: 39866254.468963

# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1275: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# <ipython-input-5-5f24788bf935>:204: RuntimeWarning: overflow encountered in square
#   mse = np.mean((preds - y) ** 2)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1275: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# <ipython-input-5-5f24788bf935>:204: RuntimeWarning: overflow encountered in square
#   mse = np.mean((preds - y) ** 2)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1275: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# Tuning Models:  34%|███▍      | 147/432 [03:18<01:07,  4.20it/s]
# Epoch 600/1000, Loss: 37277683.246790
# Epoch 700/1000, Loss: 37277683.246790
# Epoch 800/1000, Loss: 37277683.246790
# Epoch 900/1000, Loss: 37277683.246790
# Epoch 999/1000, Loss: 37277683.246790
# Epoch 0/1000, Loss: 268109757.791171
# Epoch 100/1000, Loss: 37277822.087136
# Epoch 200/1000, Loss: 37277697.342732
# Epoch 300/1000, Loss: 37277697.150075
# Epoch 400/1000, Loss: 37277697.149730
# Epoch 500/1000, Loss: 37277697.149727
# Epoch 600/1000, Loss: 37277697.149727
# Epoch 700/1000, Loss: 37277697.149727
# Epoch 800/1000, Loss: 37277697.149727
# Epoch 900/1000, Loss: 37277697.149727
# Epoch 999/1000, Loss: 37277697.149727
# Epoch 0/100, Loss: .000000
# Warning: Non-finite loss detected at epoch 1. Training stopped.
# Warning: Non-finite loss detected at epoch 0. Training stopped.
# Epoch 0/100, Loss: .000000
# Warning: Non-finite loss detected at epoch 1. Training stopped.
# ...
# Error with params {'penalty': 'l2', 'lr': 1.0, 'epochs': 500, 'batch_size': 1, 'lam': 0.1}: Input contains NaN.
# Warning: Non-finite loss detected at epoch 0. Training stopped.
# Epoch 0/500, Loss: 170282724.577307
# Epoch 100/500, Loss: 69754076.560644
# <ipython-input-5-5f24788bf935>:204: RuntimeWarning: overflow encountered in square
#   mse = np.mean((preds - y) ** 2)
# <ipython-input-5-5f24788bf935>:208: RuntimeWarning: overflow encountered in square
#   mse += (self.lam / (2 * m)) * np.sum(self.theta[1:] ** 2)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1275: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# Epoch 200/500, Loss: 76884777.171125
# Epoch 300/500, Loss: 55062684.781959
# Epoch 400/500, Loss: 89396742.848935
# Tuning Models:  94%|█████████▍| 405/432 [06:19<00:01, 15.38it/s]
# Epoch 499/500, Loss: 181183836.661354
# Epoch 0/500, Loss: 61413625.986070
# Epoch 100/500, Loss: 53585823.343219
# Epoch 200/500, Loss: 73450634.276466
# Epoch 400/500, Loss: 37328539.378189
# Epoch 499/500, Loss: 37328539.378189
# Warning: Non-finite weights detected at epoch 0. Training stopped.
# Error with params {'penalty': 'l2', 'lr': 1.0, 'epochs': 1000, 'batch_size': 1, 'lam': 0.001}: Input contains NaN.
# Warning: Non-finite weights detected at epoch 0. Training stopped.
# Error with params {'penalty': 'l2', 'lr': 1.0, 'epochs': 1000, 'batch_size': 1, 'lam': 0.01}: Input contains NaN.
# Warning: Non-finite weights detected at epoch 0. Training stopped.
# Error with params {'penalty': 'l2', 'lr': 1.0, 'epochs': 1000, 'batch_size': 1, 'lam': 0.1}: Input contains NaN.
# Warning: Non-finite loss detected at epoch 0. Training stopped.
# Epoch 0/1000, Loss: 115181163.902848
# <ipython-input-5-5f24788bf935>:204: RuntimeWarning: overflow encountered in square
#   mse = np.mean((preds - y) ** 2)
# <ipython-input-5-5f24788bf935>:208: RuntimeWarning: overflow encountered in square
#   mse += (self.lam / (2 * m)) * np.sum(self.theta[1:] ** 2)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1275: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# Epoch 100/1000, Loss: 510394605.426393
# Epoch 200/1000, Loss: 83212694.459487
# Epoch 300/1000, Loss: 100121989.255183
# Epoch 400/1000, Loss: 81825514.654679
# Epoch 500/1000, Loss: 99664113.791572
# Epoch 600/1000, Loss: 90368931.416788
# Epoch 700/1000, Loss: 62707620.446301
# Epoch 800/1000, Loss: 146337551.941233
# Epoch 900/1000, Loss: 60717808.971219
# Tuning Models:  97%|█████████▋| 421/432 [06:22<00:01,  7.17it/s]
# Epoch 999/1000, Loss: 71095893.262151
# Epoch 0/1000, Loss: 49610294.815524
# Epoch 100/1000, Loss: 485850853.874793
# Epoch 200/1000, Loss: 64298872.799249
# Epoch 300/1000, Loss: 89615990.985945
# Epoch 400/1000, Loss: 133356788.375110
# Epoch 500/1000, Loss: 427800784.767152
# Epoch 600/1000, Loss: 102356429.941670
# Epoch 700/1000, Loss: 58494022.995478
# Epoch 800/1000, Loss: 51854643.619147
# Epoch 900/1000, Loss: 51690337.500494
# Epoch 999/1000, Loss: 88805989.710456
# Epoch 0/1000, Loss: 134756929.063100
# Epoch 100/1000, Loss: 183022388.559150
# Epoch 200/1000, Loss: 93219979.298755
# Epoch 300/1000, Loss: 155555827.356844
# Epoch 400/1000, Loss: 60927881.926538
# Epoch 500/1000, Loss: 78749715.067099
# Epoch 600/1000, Loss: 57748445.274764
# Epoch 700/1000, Loss: 52215452.676677
# Tuning Models:  98%|█████████▊| 423/432 [06:24<00:02,  3.67it/s]
# Epoch 800/1000, Loss: 84721953.353473
# Epoch 900/1000, Loss: 220808055.257942
# Epoch 999/1000, Loss: 65483564.031770
# Epoch 0/1000, Loss: 223849715.092066
# Epoch 100/1000, Loss: 87086216.227050
# Epoch 200/1000, Loss: 126914907.624375
# Epoch 300/1000, Loss: 132189075.266175
FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Penalty', y='R2', data=results_df, palette=['#3498db', '#e74c3c', '#2ecc71'])
# <ipython-input-5-5f24788bf935>:406: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Batch Size', y='MSE', data=results_df, palette=['#f39c12', '#9b59b6', '#1abc9c', '#34495e'])
# <ipython-input-5-5f24788bf935>:417: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Learning Rate', y='MSE', data=results_df, palette=['#1abc9c', '#3498db', '#9b59b6', '#e74c3c'])
# ================================================================================
# PERBANDINGAN GD VS SGD
# ================================================================================
# Training model GD (full-batch)...
# Epoch 0/500, Loss: 268109756.581752
# Epoch 100/500, Loss: 37277857.480353
# Epoch 200/500, Loss: 37277732.751887
# Epoch 300/500, Loss: 37277732.560058
# Epoch 400/500, Loss: 37277732.559745
# Epoch 499/500, Loss: 37277732.559744
# Training model SGD (batch_size=1)...
# Epoch 0/500, Loss: 64656891.770891
# Epoch 100/500, Loss: 65830164.819879
# Epoch 200/500, Loss: 99013453.090465
# Epoch 300/500, Loss: 68580933.139414
# Epoch 400/500, Loss: 148498543.088927
# Epoch 499/500, Loss: 58044636.619566
# Training model mini-batch SGD (batch_size=16)...
# Epoch 0/500, Loss: 38123858.018955
# Epoch 100/500, Loss: 38089638.275299
# Epoch 200/500, Loss: 38732084.496071
# Epoch 300/500, Loss: 37946959.655629
# Epoch 400/500, Loss: 38946568.463088
# Epoch 499/500, Loss: 37884686.913164
# Training model dengan No Regularization...
# Epoch 0/500, Loss: 268109756.076828
# Epoch 100/500, Loss: 37277806.608890
# Epoch 200/500, Loss: 37277681.893688
# Epoch 300/500, Loss: 37277681.702314
# Epoch 400/500, Loss: 37277681.702019
# Epoch 499/500, Loss: 37277681.702019
# Training model dengan l1 Regularization...
# Epoch 0/500, Loss: 268109756.248263
# Epoch 100/500, Loss: 37277808.156715
# Epoch 200/500, Loss: 37277683.438592
# Epoch 300/500, Loss: 37277683.247090
# Epoch 400/500, Loss: 37277683.246790
# Epoch 499/500, Loss: 37277683.246790
# Training model dengan l2 Regularization...
# Epoch 0/500, Loss: 268109806.569197
# Epoch 100/500, Loss: 37282893.752980
# Epoch 200/500, Loss: 37282767.713425
# Epoch 300/500, Loss: 37282767.476663
# Epoch 400/500, Loss: 37282767.474557
# Epoch 499/500, Loss: 37282767.474486
# ================================================================================
# ANALISIS HASIL AKHIR
# ================================================================================
#
# ╔══════════════════════════════════════════════════════════════════╗
# ║                    KONFIGURASI MODEL TERBAIK                     ║
# ╠════════════════════════╦═══════════════════════════════════════════╣
# ║ Parameter              ║ Nilai                                     ║
# ╠════════════════════════╬═══════════════════════════════════════════╣
# ║ Regularisasi           ║ l2            ║
# ║ Learning Rate          ║ 0.1      ║
# ║ Lambda                 ║ 0.001             ║
# ║ Batch Size             ║ 16         ║
# ║ Epochs                 ║ 1000             ║
# ╠════════════════════════╬═══════════════════════════════════════════╣
# ║ MSE                    ║ 33166733.3152            ║
# ║ R²                     ║ 0.7864             ║
# ║ Training Time          ║ 0.78 detik ║
# ╚════════════════════════╩═══════════════════════════════════════════╝
